# %%
import requests
import xmltodict

url = "https://www.cbr.ru/scripts/XML_daily.asp"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="18.05.2024" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>60,7158</Value><VunitRate>60,7158</VunitRate></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>53,5219</Value><VunitRate>53,5219</VunitRate></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>115,2627</Value><VunitRate>115,2627</VunitRate></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>23,4745</Value><VunitRate>0,234745</VunitRate></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>28,2868</Value><VunitRate>28,2868</VunitRate></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>50,5499</Value><VunitRate>50,5499</VunitRate></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><Value>17,7477</Value><VunitRate>17,7477</VunitRate></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xf5 \xf4\xee\xf0\xe8\xed\xf2\xee\xe2</Name><Value>25,4382</Value><VunitRate>0,254382</VunitRate></Valute><Valute ID="R01150"><NumCode>704</NumCode><CharCode>VND</CharCode><Nominal>10000</Nominal><Name>\xc2\xfc\xe5\xf2\xed\xe0\xec\xf1\xea\xe8\xf5 \xe4\xee\xed\xe3\xee\xe2</Name><Value>37,5376</Value><VunitRate>0,00375376</VunitRate></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>1</Nominal><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>11,6830</Value><VunitRate>11,683</VunitRate></Valute><Valute ID="R01210"><NumCode>981</NumCode><CharCode>GEL</CharCode><Nominal>1</Nominal><Name>\xc3\xf0\xf3\xe7\xe8\xed\xf1\xea\xe8\xe9 \xeb\xe0\xf0\xe8</Name><Value>32,9712</Value><VunitRate>32,9712</VunitRate></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>1</Nominal><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><Value>13,2507</Value><VunitRate>13,2507</VunitRate></Valute><Valute ID="R01230"><NumCode>784</NumCode><CharCode>AED</CharCode><Nominal>1</Nominal><Name>\xc4\xe8\xf0\xf5\xe0\xec \xce\xc0\xdd</Name><Value>24,7753</Value><VunitRate>24,7753</VunitRate></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><Value>90,9873</Value><VunitRate>90,9873</VunitRate></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>\xc5\xe2\xf0\xee</Name><Value>98,7776</Value><VunitRate>98,7776</VunitRate></Valute><Valute ID="R01240"><NumCode>818</NumCode><CharCode>EGP</CharCode><Nominal>10</Nominal><Name>\xc5\xe3\xe8\xef\xe5\xf2\xf1\xea\xe8\xf5 \xf4\xf3\xed\xf2\xee\xe2</Name><Value>19,3988</Value><VunitRate>1,93988</VunitRate></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>10</Nominal><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>10,8991</Value><VunitRate>1,08991</VunitRate></Valute><Valute ID="R01280"><NumCode>360</NumCode><CharCode>IDR</CharCode><Nominal>1000 ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# {'ValCurs': {'@Date': '18.05.2024',
#   '@name': 'Foreign Currency Market',
#   'Valute': [{'@ID': 'R01010',
#     'NumCode': '036',
#     'CharCode': 'AUD',
#     'Nominal': '1',
#     'Name': 'Австралийский доллар',
#     'Value': '60,7158',
#     'VunitRate': '60,7158'},
#    {'@ID': 'R01020A',
#     'NumCode': '944',
#     'CharCode': 'AZN',
#     'Nominal': '1',
#     'Name': 'Азербайджанский манат',
#     'Value': '53,5219',
#     'VunitRate': '53,5219'},
#    {'@ID': 'R01035',
#     'NumCode': '826',
#     'CharCode': 'GBP',
#     'Nominal': '1',
#     'Name': 'Фунт стерлингов Соединенного королевства',
#     'Value': '115,2627',
#     'VunitRate': '115,2627'},
#    {'@ID': 'R01060',
#     'NumCode': '051',
#     'CharCode': 'AMD',
#     'Nominal': '100',
#     'Name': 'Армянских драмов',
#     'Value': '23,4745',
#     'VunitRate': '0,234745'},
#    {'@ID': 'R01090B',
#     'NumCode': '933',
#     'CharCode': 'BYN',
#     'Nominal': '1',
#     'Name': 'Белорусский рубль',
#     'Value': '28,2868',
#     'VunitRate': '28,2868'},
#    {'@ID': 'R01100',
#     'NumCode': '975',
#     'CharCode': 'BGN',
#     'Nominal': '1',
#     'Name': 'Болгарский лев',
#     'Value': '50,5499',
#     'VunitRate': '50,5499'},
#    {'@ID': 'R01115',
#     'NumCode': '986',
#     'CharCode': 'BRL',
#     'Nominal': '1',
#     'Name': 'Бразильский реал',
#     'Value': '17,7477',
#     'VunitRate': '17,7477'},
#    {'@ID': 'R01135',
#     'NumCode': '348',
#     'CharCode': 'HUF',
#     'Nominal': '100',
#     'Name': 'Венгерских форинтов',
#     'Value': '25,4382',
#     'VunitRate': '0,254382'},
#    {'@ID': 'R01150',
#     'NumCode': '704',
#     'CharCode': 'VND',
#     'Nominal': '10000',
#     'Name': 'Вьетнамских донгов',
#     'Value': '37,5376',
#     'VunitRate': '0,00375376'},
#    {'@ID': 'R01200',
#     'NumCode': '344',
#     'CharCode': 'HKD',
#     'Nominal': '1',
#     'Name': 'Гонконгский доллар',
#     'Value': '11,6830',
#     'VunitRate': '11,683'},
#    {'@ID': 'R01210',
#     'NumCode': '981',
#     'CharCode': 'GEL',
#     'Nominal': '1',
#     'Name': 'Грузинский лари',
#     'Value': '32,9712',
#     'VunitRate': '32,9712'},
#    {'@ID': 'R01215',
#     'NumCode': '208',
#     'CharCode': 'DKK',
#     'Nominal': '1',
#     'Name': 'Датская крона',
#     'Value': '13,2507',
#     'VunitRate': '13,2507'},
#    {'@ID': 'R01230',
#     'NumCode': '784',
#     'CharCode': 'AED',
#     'Nominal': '1',
#     'Name': 'Дирхам ОАЭ',
#     'Value': '24,7753',
#     'VunitRate': '24,7753'},
#    {'@ID': 'R01235',
#     'NumCode': '840',
#     'CharCode': 'USD',
#     'Nominal': '1',
#     'Name': 'Доллар США',
#     'Value': '90,9873',
#     'VunitRate': '90,9873'},
#    {'@ID': 'R01239',
#     'NumCode': '978',
#     'CharCode': 'EUR',
#     'Nominal': '1',
#     'Name': 'Евро',
#     'Value': '98,7776',
#     'VunitRate': '98,7776'},
#    {'@ID': 'R01240',
#     'NumCode': '818',
#     'CharCode': 'EGP',
#     'Nominal': '10',
#     'Name': 'Египетских фунтов',
#     'Value': '19,3988',
#     'VunitRate': '1,93988'},
#    {'@ID': 'R01270',
#     'NumCode': '356',
#     'CharCode': 'INR',
#     'Nominal': '10',
#     'Name': 'Индийских рупий',
#     'Value': '10,8991',
#     'VunitRate': '1,08991'},
#    {'@ID': 'R01280',
#     'NumCode': '360',
#     'CharCode': 'IDR',
#     'Nominal': '10000',
#     'Name': 'Индонезийских рупий',
#     'Value': '57,0668',
#     'VunitRate': '0,00570668'},
#    {'@ID': 'R01335',
#     'NumCode': '398',
#     'CharCode': 'KZT',
#     'Nominal': '100',
#     'Name': 'Казахстанских тенге',
#     'Value': '20,6049',
#     'VunitRate': '0,206049'},
#    {'@ID': 'R01350',
#     'NumCode': '124',
#     'CharCode': 'CAD',
#     'Nominal': '1',
#     'Name': 'Канадский доллар',
#     'Value': '66,8042',
#     'VunitRate': '66,8042'},
#    {'@ID': 'R01355',
#     'NumCode': '634',
#     'CharCode': 'QAR',
#     'Nominal': '1',
#     'Name': 'Катарский риал',
#     'Value': '24,9965',
#     'VunitRate': '24,9965'},
#    {'@ID': 'R01370',
#     'NumCode': '417',
#     'CharCode': 'KGS',
#     'Nominal': '10',
#     'Name': 'Киргизских сомов',
#     'Value': '10,3149',
#     'VunitRate': '1,03149'},
#    {'@ID': 'R01375',
#     'NumCode': '156',
#     'CharCode': 'CNY',
#     'Nominal': '1',
#     'Name': 'Китайский юань',
#     'Value': '12,5753',
#     'VunitRate': '12,5753'},
#    {'@ID': 'R01500',
#     'NumCode': '498',
#     'CharCode': 'MDL',
#     'Nominal': '10',
#     'Name': 'Молдавских леев',
#     'Value': '51,1930',
#     'VunitRate': '5,1193'},
#    {'@ID': 'R01530',
#     'NumCode': '554',
#     'CharCode': 'NZD',
#     'Nominal': '1',
#     'Name': 'Новозеландский доллар',
#     'Value': '55,6114',
#     'VunitRate': '55,6114'},
#    {'@ID': 'R01535',
#     'NumCode': '578',
#     'CharCode': 'NOK',
#     'Nominal': '10',
#     'Name': 'Норвежских крон',
#     'Value': '84,9222',
#     'VunitRate': '8,49222'},
#    {'@ID': 'R01565',
#     'NumCode': '985',
#     'CharCode': 'PLN',
#     'Nominal': '1',
#     'Name': 'Польский злотый',
#     'Value': '23,1149',
#     'VunitRate': '23,1149'},
#    {'@ID': 'R01585F',
#     'NumCode': '946',
#     'CharCode': 'RON',
#     'Nominal': '1',
#     'Name': 'Румынский лей',
#     'Value': '19,8320',
#     'VunitRate': '19,832'},
#    {'@ID': 'R01589',
#     'NumCode': '960',
#     'CharCode': 'XDR',
#     'Nominal': '1',
#     'Name': 'СДР (специальные права заимствования)',
#     'Value': '120,6728',
#     'VunitRate': '120,6728'},
#    {'@ID': 'R01625',
#     'NumCode': '702',
#     'CharCode': 'SGD',
#     'Nominal': '1',
#     'Name': 'Сингапурский доллар',
#     'Value': '67,5180',
#     'VunitRate': '67,518'},
#    {'@ID': 'R01670',
#     'NumCode': '972',
#     'CharCode': 'TJS',
#     'Nominal': '10',
#     'Name': 'Таджикских сомони',
#     'Value': '83,6388',
#     'VunitRate': '8,36388'},
#    {'@ID': 'R01675',
#     'NumCode': '764',
#     'CharCode': 'THB',
#     'Nominal': '10',
#     'Name': 'Таиландских батов',
#     'Value': '25,0875',
#     'VunitRate': '2,50875'},
#    {'@ID': 'R01700J',
#     'NumCode': '949',
#     'CharCode': 'TRY',
#     'Nominal': '10',
#     'Name': 'Турецких лир',
#     'Value': '28,2690',
#     'VunitRate': '2,8269'},
#    {'@ID': 'R01710A',
#     'NumCode': '934',
#     'CharCode': 'TMT',
#     'Nominal': '1',
#     'Name': 'Новый туркменский манат',
#     'Value': '25,9964',
#     'VunitRate': '25,9964'},
#    {'@ID': 'R01717',
#     'NumCode': '860',
#     'CharCode': 'UZS',
#     'Nominal': '10000',
#     'Name': 'Узбекских сумов',
#     'Value': '71,5309',
#     'VunitRate': '0,00715309'},
#    {'@ID': 'R01720',
#     'NumCode': '980',
#     'CharCode': 'UAH',
#     'Nominal': '10',
#     'Name': 'Украинских гривен',
#     'Value': '23,0754',
#     'VunitRate': '2,30754'},
#    {'@ID': 'R01760',
#     'NumCode': '203',
#     'CharCode': 'CZK',
#     'Nominal': '10',
#     'Name': 'Чешских крон',
#     'Value': '39,9225',
#     'VunitRate': '3,99225'},
#    {'@ID': 'R01770',
#     'NumCode': '752',
#     'CharCode': 'SEK',
#     'Nominal': '10',
#     'Name': 'Шведских крон',
#     'Value': '85,1038',
#     'VunitRate': '8,51038'},
#    {'@ID': 'R01775',
#     'NumCode': '756',
#     'CharCode': 'CHF',
#     'Nominal': '1',
#     'Name': 'Швейцарский франк',
#     'Value': '100,0960',
#     'VunitRate': '100,096'},
#    {'@ID': 'R01805F',
#     'NumCode': '941',
#     'CharCode': 'RSD',
#     'Nominal': '100',
#     'Name': 'Сербских динаров',
#     'Value': '84,3636',
#     'VunitRate': '0,843636'},
#    {'@ID': 'R01810',
#     'NumCode': '710',
#     'CharCode': 'ZAR',
#     'Nominal': '10',
#     'Name': 'Южноафриканских рэндов',
#     'Value': '49,9398',
#     'VunitRate': '4,99398'},
#    {'@ID': 'R01815',
#     'NumCode': '410',
#     'CharCode': 'KRW',
#     'Nominal': '1000',
#     'Name': 'Вон Республики Корея',
#     'Value': '67,1543',
#     'VunitRate': '0,0671543'},
#    {'@ID': 'R01820',
#     'NumCode': '392',
#     'CharCode': 'JPY',
#     'Nominal': '100',
#     'Name': 'Японских иен',
#     'Value': '58,5240',
#     'VunitRate': '0,58524'}]}}

# %%
items = []
for item in data['ValCurs']['Valute']:
    items.append(item)
item
# Out:
# {'@ID': 'R01820',
#  'NumCode': '392',
#  'CharCode': 'JPY',
#  'Nominal': '100',
#  'Name': 'Японских иен',
#  'Value': '58,5240',
#  'VunitRate': '0,58524'}

# %%
my_array = []
for item in data['ValCurs']['Valute']:
    my_set = [item['CharCode'], item['Name'], item['Value']];
    my_array.append(my_set)
    print(my_set)
# Out:
# ['AUD', 'Австралийский доллар', '60,7158']
# ['AZN', 'Азербайджанский манат', '53,5219']
# ['GBP', 'Фунт стерлингов Соединенного королевства', '115,2627']
# ['AMD', 'Армянских драмов', '23,4745']
# ['BYN', 'Белорусский рубль', '28,2868']
# ['BGN', 'Болгарский лев', '50,5499']
# ['BRL', 'Бразильский реал', '17,7477']
# ['HUF', 'Венгерских форинтов', '25,4382']
# ['VND', 'Вьетнамских донгов', '37,5376']
# ['HKD', 'Гонконгский доллар', '11,6830']
# ['GEL', 'Грузинский лари', '32,9712']
# ['DKK', 'Датская крона', '13,2507']
# ['AED', 'Дирхам ОАЭ', '24,7753']
# ['USD', 'Доллар США', '90,9873']
# ['EUR', 'Евро', '98,7776']
# ['EGP', 'Египетских фунтов', '19,3988']
# ['INR', 'Индийских рупий', '10,8991']
# ['IDR', 'Индонезийских рупий', '57,0668']
# ['KZT', 'Казахстанских тенге', '20,6049']
# ['CAD', 'Канадский доллар', '66,8042']
# ['QAR', 'Катарский риал', '24,9965']
# ['KGS', 'Киргизских сомов', '10,3149']
# ['CNY', 'Китайский юань', '12,5753']
# ['MDL', 'Молдавских леев', '51,1930']
# ['NZD', 'Новозеландский доллар', '55,6114']
# ['NOK', 'Норвежских крон', '84,9222']
# ['PLN', 'Польский злотый', '23,1149']
# ['RON', 'Румынский лей', '19,8320']
# ['XDR', 'СДР (специальные права заимствования)', '120,6728']
# ['SGD', 'Сингапурский доллар', '67,5180']
# ['TJS', 'Таджикских сомони', '83,6388']
# ['THB', 'Таиландских батов', '25,0875']
# ['TRY', 'Турецких лир', '28,2690']
# ['TMT', 'Новый туркменский манат', '25,9964']
# ['UZS', 'Узбекских сумов', '71,5309']
# ['UAH', 'Украинских гривен', '23,0754']
# ['CZK', 'Чешских крон', '39,9225']
# ['SEK', 'Шведских крон', '85,1038']
# ['CHF', 'Швейцарский франк', '100,0960']
# ['RSD', 'Сербских динаров', '84,3636']
# ['ZAR', 'Южноафриканских рэндов', '49,9398']
# ['KRW', 'Вон Республики Корея', '67,1543']
# ['JPY', 'Японских иен', '58,5240']

# %%
my_array
# Out:
# [['AUD', 'Австралийский доллар', '60,7158'],
#  ['AZN', 'Азербайджанский манат', '53,5219'],
#  ['GBP', 'Фунт стерлингов Соединенного королевства', '115,2627'],
#  ['AMD', 'Армянских драмов', '23,4745'],
#  ['BYN', 'Белорусский рубль', '28,2868'],
#  ['BGN', 'Болгарский лев', '50,5499'],
#  ['BRL', 'Бразильский реал', '17,7477'],
#  ['HUF', 'Венгерских форинтов', '25,4382'],
#  ['VND', 'Вьетнамских донгов', '37,5376'],
#  ['HKD', 'Гонконгский доллар', '11,6830'],
#  ['GEL', 'Грузинский лари', '32,9712'],
#  ['DKK', 'Датская крона', '13,2507'],
#  ['AED', 'Дирхам ОАЭ', '24,7753'],
#  ['USD', 'Доллар США', '90,9873'],
#  ['EUR', 'Евро', '98,7776'],
#  ['EGP', 'Египетских фунтов', '19,3988'],
#  ['INR', 'Индийских рупий', '10,8991'],
#  ['IDR', 'Индонезийских рупий', '57,0668'],
#  ['KZT', 'Казахстанских тенге', '20,6049'],
#  ['CAD', 'Канадский доллар', '66,8042'],
#  ['QAR', 'Катарский риал', '24,9965'],
#  ['KGS', 'Киргизских сомов', '10,3149'],
#  ['CNY', 'Китайский юань', '12,5753'],
#  ['MDL', 'Молдавских леев', '51,1930'],
#  ['NZD', 'Новозеландский доллар', '55,6114'],
#  ['NOK', 'Норвежских крон', '84,9222'],
#  ['PLN', 'Польский злотый', '23,1149'],
#  ['RON', 'Румынский лей', '19,8320'],
#  ['XDR', 'СДР (специальные права заимствования)', '120,6728'],
#  ['SGD', 'Сингапурский доллар', '67,5180'],
#  ['TJS', 'Таджикских сомони', '83,6388'],
#  ['THB', 'Таиландских батов', '25,0875'],
#  ['TRY', 'Турецких лир', '28,2690'],
#  ['TMT', 'Новый туркменский манат', '25,9964'],
#  ['UZS', 'Узбекских сумов', '71,5309'],
#  ['UAH', 'Украинских гривен', '23,0754'],
#  ['CZK', 'Чешских крон', '39,9225'],
#  ['SEK', 'Шведских крон', '85,1038'],
#  ['CHF', 'Швейцарский франк', '100,0960'],
#  ['RSD', 'Сербских динаров', '84,3636'],
#  ['ZAR', 'Южноафриканских рэндов', '49,9398'],
#  ['KRW', 'Вон Республики Корея', '67,1543'],
#  ['JPY', 'Японских иен', '58,5240']]
